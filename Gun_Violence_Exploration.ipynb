# %% [markdown]
# <a href="https://colab.research.google.com/github/Nickguild1993/Gun_Violence_Exploration/blob/main/Gun_Violence_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Trying to combine a couple different datasets of various gun violence/safety measures with the end goal being interactive plotly visualizations

# %%
# import the regulars

import pandas as pd
import numpy as np
from scipy import stats

! pip install sidetable
import sidetable
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sidetable
#   Downloading sidetable-0.9.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.7/dist-packages (from sidetable) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->sidetable) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->sidetable) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->sidetable) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0->sidetable) (1.15.0)
# Installing collected packages: sidetable
# Successfully installed sidetable-0.9.0

# %%
# get the datetime libraries

from datetime import datetime as dt
import datetime

# %%
# Import visualization libraries

import matplotlib.pyplot as plt
import seaborn as sns

import plotly.graph_objects as go
import plotly.express as px

# %% [markdown]
# Load in mass shooting data set

# %%
url = "https://raw.githubusercontent.com/Nickguild1993/Gun_Violence_Exploration/main/mass_shootings_2013_2022.csv"

df = pd.read_csv(url)
df.head(3)
# Out:
#    Incident ID      Incident Date       State City Or County  \
# 0       271363  December 29, 2014   Louisiana    New Orleans
# 1       269679  December 27, 2014  California    Los Angeles
# 2       270036  December 27, 2014  California     Sacramento
#
#                                Address  # Killed  # Injured
# 0                  Poydras and Bolivar         0          4
# 1  8800 block of South Figueroa Street         1          3
# 2             4000 block of May Street         0          4

# %% [markdown]
# Load in state population dataset

# %%
state_url = "https://raw.githubusercontent.com/Nickguild1993/Gun_Violence_Exploration/main/State_population_data.csv"
state_df = pd.read_csv("https://raw.githubusercontent.com/Nickguild1993/Gun_Violence_Exploration/main/State_population_data.csv")
state_df.head(3)
# Out:
#    rank       State       Pop  Growth   Pop2021   Pop2010  growthSince2010  \
# 0     1  California  39664128  0.0013  39613493  37319502           0.0628
# 1     2       Texas  30097526  0.0124  29730311  25241971           0.1924
# 2     3     Florida  22177997  0.0106  21944577  18845537           0.1768
#
#    Percent   density
# 0   0.1180  254.6179
# 1   0.0896  115.2138
# 2   0.0660  413.5757

# %% [markdown]
# Load in gun safety dataset

# %%
safety_url = "https://raw.githubusercontent.com/Nickguild1993/Gun_Violence_Exploration/main/State_GunLaw_Rankings.csv"
safety_df = pd.read_csv("https://raw.githubusercontent.com/Nickguild1993/Gun_Violence_Exploration/main/State_GunLaw_Rankings.csv")
safety_df.head(3)
# Out:
#          State  lawsRank grade2019  gunDeathRate
# 0   California         1         A          7.45
# 1   New Jersey         2         A          4.75
# 2  Connecticut         3        A-          4.91

# %%
safety_df["grade2019"].value_counts()
# Out:
# F     21
# A-     6
# C+     5
# C      4
# D      4
# C-     3
# A      2
# B+     2
# D-     2
# B      1
# Name: grade2019, dtype: int64

# %% [markdown]
# Need to make it straight letter grade w/o plus minus so we can make it less noisey

# %%
safety_df = safety_df.replace({"grade2019" : {"A-" : "A", "B+" : "B", "B-": "B", "C+" : "C", "C-" : "C", "D-": "D", "F": "F"}})

# %%
safety_df["grade2019"].value_counts()
# Out:
# F    21
# C    12
# A     8
# D     6
# B     3
# Name: grade2019, dtype: int64

# %% [markdown]
# rename the safety_df["grade_2019"] column

# %%
safety_df = safety_df.rename(columns={"grade2019": "Safety Grade"})
safety_df.head(3)
# Out:
#          State  lawsRank Safety Grade  gunDeathRate
# 0   California         1            A          7.45
# 1   New Jersey         2            A          4.75
# 2  Connecticut         3            A          4.91

# %% [markdown]
# #### EDA on mass shooting dataset

# %% [markdown]
# Normal inspection of dataset

# %%
print("shape of df is:", df.shape)
print("---------------------------")
print("data types: ", df.dtypes)
# Out:
# shape of df is: (3609, 7)
# ---------------------------
# data types:  Incident ID        int64
# Incident Date     object
# State             object
# City Or County    object
# Address           object
# # Killed           int64
# # Injured          int64
# dtype: object

# %%
df.stb.missing()
# 8 address obs missing, we'll drop that column anyways
# Out:
#                 missing  total   percent
# Address               8   3609  0.221668
# Incident ID           0   3609  0.000000
# Incident Date         0   3609  0.000000
# State                 0   3609  0.000000
# City Or County        0   3609  0.000000
# # Killed              0   3609  0.000000
# # Injured             0   3609  0.000000

# %% [markdown]
# Adding a column for total victims - deaths plus injuries

# %%
df["# Victims"] = df["# Killed"] + df["# Injured"]
df.head(3)
# Out:
#    Incident ID Incident Date       State City Or County  \
# 0       271363    2014-12-29   Louisiana    New Orleans
# 1       269679    2014-12-27  California    Los Angeles
# 2       270036    2014-12-27  California     Sacramento
#
#                                Address  # Killed  # Injured  # Victims
# 0                  Poydras and Bolivar         0          4          4
# 1  8800 block of South Figueroa Street         1          3          4
# 2             4000 block of May Street         0          4          4

# %%
df.columns
# Out:
# Index(['Incident ID', 'Incident Date', 'State', 'City Or County', 'Address',
#        '# Killed', '# Injured', '# Victims'],
#       dtype='object')

# %% [markdown]
# Need to change the "Incident Date" data type to a datetime object

# %%
# changing dtype of incident date to datetime

df["Incident Date"] = pd.to_datetime(df["Incident Date"], infer_datetime_format=True)
df.head(3)
# Out:
#    Incident ID Incident Date       State City Or County  \
# 0       271363    2014-12-29   Louisiana    New Orleans
# 1       269679    2014-12-27  California    Los Angeles
# 2       270036    2014-12-27  California     Sacramento
#
#                                Address  # Killed  # Injured
# 0                  Poydras and Bolivar         0          4
# 1  8800 block of South Figueroa Street         1          3
# 2             4000 block of May Street         0          4

# %%
# frequency tables with side table

df.stb.freq(["State"]).style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_cff1c_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >State</th>
#       <th class="col_heading level0 col1" >count</th>
#       <th class="col_heading level0 col2" >percent</th>
#       <th class="col_heading level0 col3" >cumulative_count</th>
#       <th class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cff1c_row0_col0" class="data row0 col0" >Illinois</td>
#       <td id="T_cff1c_row0_col1" class="data row0 col1" >374</td>
#       <td id="T_cff1c_row0_col2" class="data row0 col2" >10.362981</td>
#       <td id="T_cff1c_row0_col3" class="data row0 col3" >374</td>
#       <td id="T_cff1c_row0_col4" class="data row0 col4" >10.362981</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row1_col0" class="data row1 col0" >California</td>
#       <td id="T_cff1c_row1_col1" class="data row1 col1" >340</td>
#       <td id="T_cff1c_row1_col2" class="data row1 col2" >9.420892</td>
#       <td id="T_cff1c_row1_col3" class="data row1 col3" >714</td>
#       <td id="T_cff1c_row1_col4" class="data row1 col4" >19.783874</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row2_col0" class="data row2 col0" >Texas</td>
#       <td id="T_cff1c_row2_col1" class="data row2 col1" >244</td>
#       <td id="T_cff1c_row2_col2" class="data row2 col2" >6.760876</td>
#       <td id="T_cff1c_row2_col3" class="data row2 col3" >958</td>
#       <td id="T_cff1c_row2_col4" class="data row2 col4" >26.544749</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row3_col0" class="data row3 col0" >Florida</td>
#       <td id="T_cff1c_row3_col1" class="data row3 col1" >218</td>
#       <td id="T_cff1c_row3_col2" class="data row3 col2" >6.040454</td>
#       <td id="T_cff1c_row3_col3" class="data row3 col3" >1176</td>
#       <td id="T_cff1c_row3_col4" class="data row3 col4" >32.585204</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row4_col0" class="data row4 col0" >Louisiana</td>
#       <td id="T_cff1c_row4_col1" class="data row4 col1" >168</td>
#       <td id="T_cff1c_row4_col2" class="data row4 col2" >4.655029</td>
#       <td id="T_cff1c_row4_col3" class="data row4 col3" >1344</td>
#       <td id="T_cff1c_row4_col4" class="data row4 col4" >37.240233</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row5_col0" class="data row5 col0" >Pennsylvania</td>
#       <td id="T_cff1c_row5_col1" class="data row5 col1" >167</td>
#       <td id="T_cff1c_row5_col2" class="data row5 col2" >4.627321</td>
#       <td id="T_cff1c_row5_col3" class="data row5 col3" >1511</td>
#       <td id="T_cff1c_row5_col4" class="data row5 col4" >41.867553</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row6_col0" class="data row6 col0" >New York</td>
#       <td id="T_cff1c_row6_col1" class="data row6 col1" >166</td>
#       <td id="T_cff1c_row6_col2" class="data row6 col2" >4.599612</td>
#       <td id="T_cff1c_row6_col3" class="data row6 col3" >1677</td>
#       <td id="T_cff1c_row6_col4" class="data row6 col4" >46.467165</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row7_col0" class="data row7 col0" >Ohio</td>
#       <td id="T_cff1c_row7_col1" class="data row7 col1" >141</td>
#       <td id="T_cff1c_row7_col2" class="data row7 col2" >3.906899</td>
#       <td id="T_cff1c_row7_col3" class="data row7 col3" >1818</td>
#       <td id="T_cff1c_row7_col4" class="data row7 col4" >50.374065</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row8_col0" class="data row8 col0" >Georgia</td>
#       <td id="T_cff1c_row8_col1" class="data row8 col1" >137</td>
#       <td id="T_cff1c_row8_col2" class="data row8 col2" >3.796065</td>
#       <td id="T_cff1c_row8_col3" class="data row8 col3" >1955</td>
#       <td id="T_cff1c_row8_col4" class="data row8 col4" >54.170130</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row9_col0" class="data row9 col0" >Missouri</td>
#       <td id="T_cff1c_row9_col1" class="data row9 col1" >117</td>
#       <td id="T_cff1c_row9_col2" class="data row9 col2" >3.241895</td>
#       <td id="T_cff1c_row9_col3" class="data row9 col3" >2072</td>
#       <td id="T_cff1c_row9_col4" class="data row9 col4" >57.412025</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row10_col0" class="data row10 col0" >Tennessee</td>
#       <td id="T_cff1c_row10_col1" class="data row10 col1" >113</td>
#       <td id="T_cff1c_row10_col2" class="data row10 col2" >3.131061</td>
#       <td id="T_cff1c_row10_col3" class="data row10 col3" >2185</td>
#       <td id="T_cff1c_row10_col4" class="data row10 col4" >60.543087</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row11_col0" class="data row11 col0" >Michigan</td>
#       <td id="T_cff1c_row11_col1" class="data row11 col1" >108</td>
#       <td id="T_cff1c_row11_col2" class="data row11 col2" >2.992519</td>
#       <td id="T_cff1c_row11_col3" class="data row11 col3" >2293</td>
#       <td id="T_cff1c_row11_col4" class="data row11 col4" >63.535605</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row12_col0" class="data row12 col0" >Maryland</td>
#       <td id="T_cff1c_row12_col1" class="data row12 col1" >108</td>
#       <td id="T_cff1c_row12_col2" class="data row12 col2" >2.992519</td>
#       <td id="T_cff1c_row12_col3" class="data row12 col3" >2401</td>
#       <td id="T_cff1c_row12_col4" class="data row12 col4" >66.528124</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row13_col0" class="data row13 col0" >North Carolina</td>
#       <td id="T_cff1c_row13_col1" class="data row13 col1" >102</td>
#       <td id="T_cff1c_row13_col2" class="data row13 col2" >2.826268</td>
#       <td id="T_cff1c_row13_col3" class="data row13 col3" >2503</td>
#       <td id="T_cff1c_row13_col4" class="data row13 col4" >69.354392</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row14_col0" class="data row14 col0" >Alabama</td>
#       <td id="T_cff1c_row14_col1" class="data row14 col1" >95</td>
#       <td id="T_cff1c_row14_col2" class="data row14 col2" >2.632308</td>
#       <td id="T_cff1c_row14_col3" class="data row14 col3" >2598</td>
#       <td id="T_cff1c_row14_col4" class="data row14 col4" >71.986700</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row15_col0" class="data row15 col0" >South Carolina</td>
#       <td id="T_cff1c_row15_col1" class="data row15 col1" >93</td>
#       <td id="T_cff1c_row15_col2" class="data row15 col2" >2.576891</td>
#       <td id="T_cff1c_row15_col3" class="data row15 col3" >2691</td>
#       <td id="T_cff1c_row15_col4" class="data row15 col4" >74.563591</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row16_col0" class="data row16 col0" >New Jersey</td>
#       <td id="T_cff1c_row16_col1" class="data row16 col1" >87</td>
#       <td id="T_cff1c_row16_col2" class="data row16 col2" >2.410640</td>
#       <td id="T_cff1c_row16_col3" class="data row16 col3" >2778</td>
#       <td id="T_cff1c_row16_col4" class="data row16 col4" >76.974231</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row17_col0" class="data row17 col0" >Virginia</td>
#       <td id="T_cff1c_row17_col1" class="data row17 col1" >81</td>
#       <td id="T_cff1c_row17_col2" class="data row17 col2" >2.244389</td>
#       <td id="T_cff1c_row17_col3" class="data row17 col3" >2859</td>
#       <td id="T_cff1c_row17_col4" class="data row17 col4" >79.218620</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row18_col0" class="data row18 col0" >Indiana</td>
#       <td id="T_cff1c_row18_col1" class="data row18 col1" >75</td>
#       <td id="T_cff1c_row18_col2" class="data row18 col2" >2.078138</td>
#       <td id="T_cff1c_row18_col3" class="data row18 col3" >2934</td>
#       <td id="T_cff1c_row18_col4" class="data row18 col4" >81.296758</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row19_col0" class="data row19 col0" >Mississippi</td>
#       <td id="T_cff1c_row19_col1" class="data row19 col1" >70</td>
#       <td id="T_cff1c_row19_col2" class="data row19 col2" >1.939595</td>
#       <td id="T_cff1c_row19_col3" class="data row19 col3" >3004</td>
#       <td id="T_cff1c_row19_col4" class="data row19 col4" >83.236354</td>
#     </tr>
#     <tr>
#       <td id="T_cff1c_row20_col0" class="data row20 col0" >District of Columbia</td>
#       <td id="T_cff1c_row20_col1" class="data row20 col1" >59

# %%
df.columns
# Out:
# Index(['Incident ID', 'Incident Date', 'State', 'City Or County', 'Address',
#        '# Killed', '# Injured', '# Victims'],
#       dtype='object')

# %% [markdown]
# Creating aggregate function dictionary for groupbys

# %%
agg_deaths = {
    "# Killed" : ["sum", "mean", "min", "max", "var"]
}

agg_injured = {
    "# Injured" : ["sum", "mean",  "min", "max", "var"]
}

agg_victims = {
    "# Victims" : [ "sum", "mean",  "min", "max", "var"]
}

# %%
# Looking at state deaths 
df_deaths = df.groupby("State").agg(agg_deaths).reset_index().round(2)
df_deaths[:5]
# Out:
#         State # Killed
#                    sum  mean min max   var
# 0     Alabama       98  1.03   0   7  1.52
# 1      Alaska        6  1.20   0   4  2.70
# 2     Arizona       65  1.76   0   5  2.47
# 3    Arkansas       41  0.95   0   5  1.43
# 4  California      394  1.16   0  16  3.08

# %%
df_deaths.columns
# Out:
# MultiIndex([(   'State',     ''),
#             ('# Killed',  'sum'),
#             ('# Killed', 'mean'),
#             ('# Killed',  'min'),
#             ('# Killed',  'max'),
#             ('# Killed',  'var')],
#            )

# %%
df_deaths = df_deaths.sort_values(by=[("# Killed", "sum")], ascending = False)
# state_deaths.style.hide_index() can't chain wiht either head or loc?
df_deaths.head(5)
# Out:
#          State # Killed
#                     sum  mean min max    var
# 41       Texas      419  1.72   0  27   9.27
# 4   California      394  1.16   0  16   3.08
# 9      Florida      285  1.31   0  50  13.85
# 12    Illinois      257  0.69   0   6   1.01
# 10     Georgia      149  1.09   0   8   1.95

# %% [markdown]
# Looking at state injuries

# %%
# agg_injured

df_injured = df.groupby(["State"]).agg(agg_injured).reset_index().round(2)
df_injured = df_injured.sort_values(by=[("# Injured", "sum")], ascending = False)
df_injured.head(5)
# Out:
#          State # Injured
#                      sum  mean min max    var
# 12    Illinois      1594  4.26   0  15   2.98
# 4   California      1350  3.97   0  19   4.18
# 41       Texas      1018  4.17   0  23  11.08
# 9      Florida       962  4.41   0  53  16.96
# 17   Louisiana       723  4.30   0  17   4.78

# %%
df.head(3)
# Out:
#    Incident ID Incident Date       State City Or County  \
# 0       271363    2014-12-29   Louisiana    New Orleans
# 1       269679    2014-12-27  California    Los Angeles
# 2       270036    2014-12-27  California     Sacramento
#
#                                Address  # Killed  # Injured  # Victims
# 0                  Poydras and Bolivar         0          4          4
# 1  8800 block of South Figueroa Street         1          3          4
# 2             4000 block of May Street         0          4          4

# %% [markdown]
# #### Joining the safety_df (refer to cell 10) with the df

# %%
# Not a great join- need to fix this so I don't have to run next cell
combined_df = df.join(safety_df.set_index("State"), on ="State", how = "left")
combined_df.head(3)
# Out:
#    Incident ID Incident Date       State City Or County  \
# 0       271363    2014-12-29   Louisiana    New Orleans
# 1       269679    2014-12-27  California    Los Angeles
# 2       270036    2014-12-27  California     Sacramento
#
#                                Address  # Killed  # Injured  # Victims  \
# 0                  Poydras and Bolivar         0          4          4
# 1  8800 block of South Figueroa Street         1          3          4
# 2             4000 block of May Street         0          4          4
#
#    lawsRank Safety Grade  gunDeathRate
# 0      32.0            F         21.31
# 1       1.0            A          7.45
# 2       1.0            A          7.45

# %% [markdown]
# Remove excess columns

# %%
combined_df = combined_df.drop(["Address", "Incident ID"], axis=1)
combined_df.columns
# Out:
# Index(['Incident Date', 'State', 'City Or County', '# Killed', '# Injured',
#        '# Victims', 'lawsRank', 'Safety Grade', 'gunDeathRate'],
#       dtype='object')

# %%
df = px.data.gapminder()
px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country",
           log_x=True, size_max=55, range_x=[100,100000], range_y=[25,90])


px.scatter(df, x ="")
